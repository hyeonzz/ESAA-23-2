# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeonzz/ESAA-23-2/blob/main/Pandas_pg81_119.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##04-1. 데이터 시각화가 필요한 이유
# ### 데이터 그룹이 서로 다른 데이터 패턴을 가지고 있다는 것을 쉽게 알 수 있음.

# %%
#1.앤스콤 데이터 집합 불러오기
import seaborn as sns
anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
#2.matplotlib 라이브러리로 그래프 그리기
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#3. dataset 열에서 데이터 값이 1인 거 추출 -> 첫 번째 데이터 그룹을 추출
dataset_1 = anscombe[anscombe['dataset'] == 'I']

# %%
#4. 선 그래프 그리기
plt.plot(dataset_1['x'], dataset_1['y'])

# %%
#점 그래프 그리기
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %% [markdown]
# ###앤스콤 데이터 집합 모두 사용해 그래프 만들기

# %% [markdown]
# ###matplotlib 라이브러리로 그래프 그리기

# %% [markdown]
# > ### 1. 전체 그래프가 위치할 기본 틀 만들기 -> fig = plt.figure()
# > ### 2. 그래프를 그려 넣을 그래프 격자 만들기 -> add_subplot 메서드
# > ### 3. 격자에 그래프를 하나씩 추가하기 -> plot 메서드
# > * ### 그래프 제목 추가하기 -> set_title 메서드
# > * ### 기본 틀에 제목 추가하기 -> suptitle 메서드
# > * ### 각 그래프의 레이아웃 조절하기 -> tight_layout 메서드
# > ### -> 그래프를 확인하기 위해 fig 반드시 입력

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
#1.그래프 격자가 위치할 기본 틀 만들기
fig = plt.figure()

#2.그래프 격자 그리기
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
#3.그래프 그리기
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

fig

# %%
#그래프 제목 추가하기
axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")

fig

# %%
fig.suptitle("Anscombe Data")

fig

# %%
#그래프의 레이아웃 조절 -> 그래프의 이름과 숫자 겹침 해결
fig.tight_layout()

fig

# %% [markdown]
# ##04-2. matplotlib 라이브러리 자유자재로 사용하기

# %% [markdown]
# ###기초 그래프 그리기 - 히스토그램, 산점도 그래프, 박스 그래프

# %%
#데이터 집합 불러오기 & 변수에 저장
tips = sns.load_dataset("tips")
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
#기본 틀 마련 & 그래프 격자 구성
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)

# %% [markdown]
# ###히스토그램
#  * #### 데이터 프레임의 열 데이터 분포와 빈도를 살펴봄.
#  * #### 변수 하나만 사용해서 그린 그래프 ->> 일변량 그래프
#  * #### hist 메서드 이용
#  * #### bins 인잣값으로 x축 간격 조정

# %%
#히스토그램
axes1.hist(tips['total_bill'], bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig

# %% [markdown]
# ###산점도 그래프
# * #### 변수 2개를 사용해서 만듦. ->> 이변량 그래프 그래프
# * #### scatter 메서드 이용

# %%
#산점도 그래프 그리기
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ###박스 그래프
# * #### 이산형 변수와 연속형 변수를 함께 사용.
# * #### boxplot 메서드 이용

# %%
#박스 그래프 그리기
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['sex'] == 'Female']['tip'],
               tips[tips['sex'] == 'Male']['tip']],
              labels = ['Female', 'Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# ###다변량 그래프 그리기: 3개 이상의 변수를 사용한 그래프

# %%
# 위의 산점도에 성별 변수 추가
# 각 문자열을 정수로 치환하는 함수
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size']*10,
    c=tips['sex_color'],
    alpha=0.5)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ##04-3. seaborn 라이브러리 자유자재로 사용하기

# %% [markdown]
# ###단변량 그래프 그리기 - 히스토그램

# %%
import seaborn as sns

tips = sns.load_dataset("tips")

# %% [markdown]
# * #### subplots 메서드: 기본 틀 만들기
# * #### distplot 메서드: 열 데이터 전달

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# <ipython-input-26-071bdf8959b6>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'])
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %% [markdown]
# ####밀집도 그래프 제외 -> kde=False
# ####히스토그램 그래프 제외 -> hist=False

# %%
#밀집도 그래프 제외
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], kde=False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <ipython-input-106-29ef41561e71>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], kde=False)
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist=False)
ax.set_title('Total BIll Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')
# Out:
# <ipython-input-107-ba7afc232afc>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], hist=False)
# Text(0, 0.5, 'Unit Probability')

# %%
#히스토그램 + 밀집도 + 양탄자 그래프
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True)
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')
# Out:
# <ipython-input-108-177ef4c49b0e>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], rug=True)
# Text(0.5, 0, 'Total Bill')

# %%
ax = plt.subplots()
ax = sns.countplot('day', data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-bd2b608afbd6> in <cell line: 2>()
#       1 ax = plt.subplots()
# ----> 2 ax = sns.countplot('day', data=tips)
#       3 ax.set_title('Count of days')
#       4 ax.set_xlabel('Day of the Week')
#       5 ax.set_ylabel('Frequency')
#
# TypeError: countplot() got multiple values for argument 'data'

# %% [markdown]
# ###다양한 종류의 이변량 그래프 그리기

# %% [markdown]
# ###1. seaborn 라이브러리로 산점도 그래프 그리기

# %% [markdown]
# #### * regplot 메서드 이용
# #### * 회귀선 제거 -> fit_reg = False

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
#회귀선 제거
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
#  * #### joint 메서드 -> 산점도 그래프와 히스토그램을 한 번에 그림

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
hexbin = sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")
hexbin.set_axis_labels(xlabel = 'Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %%
#이차원 밀집도 그리기
ax = plt.subplots()
ax = sns.kdeplot(data=tips['total_bill'],
                 data2=tips['tip'],
                 shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <ipython-input-115-08bd026902be>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(data=tips['total_bill'],
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-08bd026902be> in <cell line: 3>()
#       1 #이차원 밀집도 그리기
#       2 ax = plt.subplots()
# ----> 3 ax = sns.kdeplot(data=tips['total_bill'],
#       4                  data2=tips['tip'],
#       5                  shade=True)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1696
# ...

# %%
#바 그래프 그리기
ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bil;')
# Out:
# Text(0, 0.5, 'Average total bil;')

# %%
#박스 그래프 그리기
ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
#커널 밀도를 추정한 바이올린 그래프
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', data=tips)
ax.set_title('Violin plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
#관계 그래프 그리기
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot, rug=True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ###다변량 그래프 그리기

# %%
#seaborn 라이브러리로 바이올린 그래프 그리기 - 색상 추가
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
#산점도, 관계 그래프 그리기 - 색상 추가
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)

# %%
fig = sns.pairplot(tips, hue='sex')

# %%
#산점도 그래프의 크기와 모양 조절하기
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
                     scatter_kws={'s':tips['size']*10})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-29abd6db7770> in <cell line: 2>()
#       1 #산점도 그래프의 크기와 모양 조절하기
# ----> 2 scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
#       3                      scatter_kws={'s':tips['size']*10})
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     633         scatter_kws=scatter_kws, line_kws=line_kws,
#     634     )
# --> 635     facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
# ...

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
                     markers=['o','x'], scatter_kws={'s':tips['size']*10})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-b532c389d378> in <cell line: 1>()
# ----> 1 scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
#       2                      markers=['o','x'], scatter_kws={'s':tips['size']*10})
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     633         scatter_kws=scatter_kws, line_kws=line_kws,
#     634     )
# --> 635     facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
#     636     facets.set_axis_labels(x, y)
#     637
# ...

# %%
#4개의 데이터 그룹에 대한 그래프 한 번에 그리기
anscomebe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False)

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False,
                           col='dataset', col_wrap=2)

# %% [markdown]
# ###facetGrid

# %%
facet = sns.FacetGrid(tips, col='time')
facet,map(sns.distplot, 'total_bill', rug=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-e63457292d31> in <cell line: 2>()
#       1 facet = sns.FacetGrid(tips, col='time')
# ----> 2 facet,map(sns.distplot, 'total_bill', rug=True)
#
# TypeError: map() takes no keyword arguments

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex')
facet = facet.map(plt.scatter, 'total_bill', 'tip')
facet = facet.add_legend()

# %%
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex')
facet.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# ##04-4. 데이터프레임과 시리즈로 그래프 그리기

# %% [markdown]
# ###데이터프레임과 시리즈로 그래프 그리기

# %%
ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

# %%
fig, ax = plt.subplots()
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

# %%
ax = plt.subplots()
ax = tips['tip'].plot.kde()

# %%
fig, ax = plt.subplots()
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips.plot.box(ax=ax)

# %% [markdown]
# ##04-5.seaborn 라이브러리로 그래프 스타일 설정하기

# %% [markdown]
# ###그래프에 스타일 적용하기

# %%
fig, ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
fig = plt.figure()

seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']

for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2,3,plot_position)
        violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
        violin.set_title(style)

fig.tight_layout()
