# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeonzz/ESAA-23-2/blob/main/YB_9_15_%EA%B3%BC%EC%A0%9C_%EB%AC%B8%EC%A0%9C_tips_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %%
data = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv')
data
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = data

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips_drop=tips.drop('Unnamed: 0',axis=1)
tips_drop
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(tips_drop['total_bill'], bins=10)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips_drop['total_bill'],
    y=tips_drop['tip']
    )
axes1.set_title('Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
fig = sns.pairplot(tips_drop)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
ax = plt.subplots()
ax = sns.barplot(x='day', y='total_bill', data=tips_drop)
ax.set_title('Bar plot of average total bill for day')
ax.set_xlabel('Day')
ax.set_ylabel('Average total bil')
# Out:
# Text(0, 0.5, 'Average total bil')

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %%
tips_drop['sex_color'] = tips_drop['sex'].apply(recode_sex)

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips_drop['tip'],
    y=tips_drop['day'],
    c=tips_drop['sex_color'],
    )
axes1.set_title('Tip vs Day Colored by Sex')
axes1.set_xlabel('Tip')
axes1.set_ylabel('Day')
# Out:
# Text(0, 0.5, 'Day')

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips_drop)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
lunch = tips_drop[tips_drop['time'] == 'Lunch']
dinner = tips_drop[tips_drop['time']== 'Dinner']

# %%
ax_lunch = plt.subplot(1,2,1)
ax_dinner = plt.subplot(1,2,2)

ax_lunch.hist(lunch['tip'], bins=10)
ax_lunch.set_title('Tip Histogram at Lunch')
ax_lunch.set_xlabel('Tip')
ax_lunch.set_ylabel('Frequency')

ax_dinner .hist(dinner['tip'], bins=10)
ax_dinner.set_title('Tip Histogram at Dinner')
ax_dinner.set_xlabel('Tip')
ax_dinner.set_ylabel('Frequency')

fig

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
male_tips = tips_drop[tips_drop['sex']=='Male']
female_tips = tips_drop[tips_drop['sex']=='Female']

# %%
scatter_plot = plt.figure()
male_plot = scatter_plot.add_subplot(1,2,1)
female_plot = scatter_plot.add_subplot(1,2,2)

male_plot.scatter(male_tips['total_bill'],male_tips['tip'])
axes1.set_title('Male Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

female_plot.scatter(female_tips['total_bill'],female_tips['tip'])
axes1.set_title('Female Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

fig

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.

# %% [markdown]
# ### Create a scatter plot presenting the relationship between total_bill and tip with a regression line and range of standard error

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips_drop)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')
